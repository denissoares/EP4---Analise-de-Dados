# %% [markdown]
# # Média de nota por ano de conclusão do ensino médio - Enem 2018

# %%
import pandas as pd
low_memory=False
# %matplotlib inline
pd.options.display.max_columns = 80
pd.options.display.max_rows = 90

# %% [markdown]
# Lendo CSV para DataFrame

# %%
filename = 'MICRODADOS_ENEM_2018.csv'
df = pd.read_csv(filename, sep = ';',encoding = 'ISO-8859-1')

# %%
df.shape
# Out:
# (5513747, 137)

# %%
df.describe()
# Out:
#        NU_INSCRICAO     NU_ANO  CO_MUNICIPIO_RESIDENCIA  CO_UF_RESIDENCIA  \
# count  5.513747e+06  5513747.0             5.513747e+06      5.513747e+06
# mean   1.800104e+11     2018.0             3.114727e+06      3.099416e+01
# std    1.917637e+06        0.0             9.930315e+05      9.901276e+00
# min    1.800072e+11     2018.0             1.100015e+06      1.100000e+01
# 25%    1.800088e+11     2018.0             2.408102e+06      2.400000e+01
# 50%    1.800104e+11     2018.0             3.136702e+06      3.100000e+01
# 75%    1.800120e+11     2018.0             3.550308e+06      3.500000e+01
# max    1.800140e+11     2018.0             5.300108e+06      5.300000e+01
#
#            NU_IDADE  TP_ESTADO_CIVIL   TP_COR_RACA  TP_NACIONALIDADE  \
# count  5.513650e+06     5.296110e+06  5.513747e+06      5.513747e+06
# mean   2.237222e+01     1.197082e-01  2.126976e+00      1.038818e+00
# std    7.594597e+00     3.752605e-01  1.017869e+00      2.324415e-01
# ...

# %%
df.sample(10)
# Out:
#          NU_INSCRICAO  NU_ANO  CO_MUNICIPIO_RESIDENCIA  \
# 695194   180008935644    2018                  3105400
# 3598982  180011383517    2018                  3106200
# 3651122  180011950109    2018                  2616407
# 1603260  180007549103    2018                  1100205
# 2429079  180010048052    2018                  3118809
# 1779599  180007604283    2018                  3505500
# 164598   180008937234    2018                  1302603
# 315838   180007529583    2018                  2927408
# 3048037  180011050506    2018                  1301902
# 1651843  180008501285    2018                  2800308
#
#         NO_MUNICIPIO_RESIDENCIA  CO_UF_RESIDENCIA SG_UF_RESIDENCIA  NU_IDADE  \
# 695194          Barão de Cocais                31               MG      19.0
# 3598982          Belo Horizonte                31               MG      18.0
# 3651122  Vitória de Santo Antão                26               PE      20.0
# ...

# %% [markdown]
# Separando os campo que serão usados

# %%
df_notas = df.loc[:,['TP_ANO_CONCLUIU','NU_NOTA_CN' ,'NU_NOTA_CH', 'NU_NOTA_LC', 'NU_NOTA_MT','NU_NOTA_REDACAO']]

# %%
df_notas.sample(10)
# Out:
#          TP_ANO_CONCLUIU  NU_NOTA_CN  NU_NOTA_CH  NU_NOTA_LC  NU_NOTA_MT  \
# 5270284                1       440.2       545.5       519.1       473.4
# 4133302                0       459.3       405.0       431.1       408.5
# 3570907                0       496.0       553.3       520.5       503.3
# 2674190                1       447.6       581.9       566.3       382.6
# 1048022               12       405.9       429.9       331.8       378.1
# 4767317                0         NaN         NaN         NaN         NaN
# 2235392                0         NaN         NaN         NaN         NaN
# 3026377                3       378.8       523.7       415.8       389.9
# 2869490                0       425.2       606.7       564.9       569.1
# 4425337               12       572.2       480.5       471.5       465.9
#
#          NU_NOTA_REDACAO
# 5270284            360.0
# 4133302            360.0
# 3570907            500.0
# 2674190            340.0
# 1048022            300.0
# ...

# %% [markdown]
# Execução do cálculo da média geral

# %%
df_notas['MEDIA'] = (df_notas['NU_NOTA_CN'] + df_notas['NU_NOTA_CH'] +
df_notas['NU_NOTA_LC'] + df_notas['NU_NOTA_MT'] + df_notas['NU_NOTA_REDACAO'])/5

# %%
df_notas.sample(10)
# Out:
#          TP_ANO_CONCLUIU  NU_NOTA_CN  NU_NOTA_CH  NU_NOTA_LC  NU_NOTA_MT  \
# 5281614                2       409.8       433.2       484.9       493.9
# 1821390                4         NaN         NaN         NaN         NaN
# 1079236                1       472.6       636.8       556.9       410.9
# 5254910                0       410.3       530.8       444.7       590.9
# 666578                 0       585.0       632.3       613.5       539.9
# 1708564                0       655.1       654.8       598.8       653.7
# 3527648                3       434.6       507.3       485.1       454.8
# 2732640                0         NaN         NaN         NaN         NaN
# 4396624                0       474.1       609.2       564.5       424.8
# 1622616                1       624.5       704.3       687.5       717.6
#
#          NU_NOTA_REDACAO   MEDIA
# 5281614            280.0  420.36
# 1821390              NaN     NaN
# 1079236            420.0  499.44
# ...

# %% [markdown]
# Converter código do ano, para ano específico

# %%
df_notas.loc [df_notas['TP_ANO_CONCLUIU'] == 0, 'ANO_CONCLUSAO_TRATADO'] = 'Não Informado'
df_notas.loc [df_notas['TP_ANO_CONCLUIU'] == 1, 'ANO_CONCLUSAO_TRATADO'] = 2017
df_notas.loc [df_notas['TP_ANO_CONCLUIU'] == 2, 'ANO_CONCLUSAO_TRATADO'] = 2016
df_notas.loc [df_notas['TP_ANO_CONCLUIU'] == 3, 'ANO_CONCLUSAO_TRATADO'] = 2015
df_notas.loc [df_notas['TP_ANO_CONCLUIU'] == 4, 'ANO_CONCLUSAO_TRATADO'] = 2014
df_notas.loc [df_notas['TP_ANO_CONCLUIU'] == 5, 'ANO_CONCLUSAO_TRATADO'] = 2013
df_notas.loc [df_notas['TP_ANO_CONCLUIU'] == 6, 'ANO_CONCLUSAO_TRATADO'] = 2012
df_notas.loc [df_notas['TP_ANO_CONCLUIU'] == 7, 'ANO_CONCLUSAO_TRATADO'] = 2011
df_notas.loc [df_notas['TP_ANO_CONCLUIU'] == 8, 'ANO_CONCLUSAO_TRATADO'] = 2010
df_notas.loc [df_notas['TP_ANO_CONCLUIU'] == 9, 'ANO_CONCLUSAO_TRATADO'] = 2009
df_notas.loc [df_notas['TP_ANO_CONCLUIU'] == 10, 'ANO_CONCLUSAO_TRATADO'] = 2008
df_notas.loc [df_notas['TP_ANO_CONCLUIU'] == 11, 'ANO_CONCLUSAO_TRATADO'] = 2007
df_notas.loc [df_notas['TP_ANO_CONCLUIU'] == 12, 'ANO_CONCLUSAO_TRATADO'] = 'Antes de 2007'

# %%
df_notas.sample(10)
# Out:
#          TP_ANO_CONCLUIU  NU_NOTA_CN  NU_NOTA_CH  NU_NOTA_LC  NU_NOTA_MT  \
# 2253257                7       408.7       414.6       416.3       436.8
# 4549745                0         NaN         NaN         NaN         NaN
# 4682373                4         NaN         NaN         NaN         NaN
# 89422                  8         NaN         NaN         NaN         NaN
# 2050566                3       517.9       593.6       556.1       485.8
# 5292549                5         NaN         NaN         NaN         NaN
# 679322                 0         NaN       620.8       590.4         NaN
# 4161702                0       553.3       611.7       543.0       526.9
# 934771                 3       718.9       670.0       654.1       758.9
# 1876044                0       552.0       688.1       633.8       678.4
#
#          NU_NOTA_REDACAO   MEDIA ANO_CONCLUSAO_TRATADO
# 2253257            340.0  403.28                  2011
# ...

# %% [markdown]
# Agrupamento dos dados por ano e ordenando pela maior média

# %%
df_notas.groupby('ANO_CONCLUSAO_TRATADO').mean().sort_values('MEDIA', ascending=False)
# Out:
#                        TP_ANO_CONCLUIU  NU_NOTA_CN  NU_NOTA_CH  NU_NOTA_LC  \
# ANO_CONCLUSAO_TRATADO
# 2017                                 1  498.397766  571.168391  530.887899
# 2016                                 2  498.402620  571.378340  531.618248
# 2015                                 3  496.140695  569.834656  529.793790
# 2014                                 4  495.270204  570.903510  530.540395
# 2013                                 5  494.057751  571.339043  530.014313
# 2011                                 7  492.986271  573.707796  530.347289
# Não Informado                        0  491.367067  563.082534  523.779431
# 2012                                 6  492.350857  571.864566  529.222509
# 2008                                10  493.852899  574.862137  526.734527
# 2009                                 9  491.945315  573.252475  527.020062
# 2010                                 8  491.063178  571.239522  526.244967
# ...

# %% [markdown]
# Separando colunas para geração de gráfico

# %%
df_notas_media = df_notas.loc[:,['ANO_CONCLUSAO_TRATADO','MEDIA']]

# %%
df_notas_media1 = df_notas_media.groupby('ANO_CONCLUSAO_TRATADO').mean().sort_values('MEDIA').plot(kind='barh', figsize=(10,10))
df_notas_media1.set_xlim(500,545)
# Out:
# (500, 545)

# %%
df_notas_media2 = df_notas_media.groupby('ANO_CONCLUSAO_TRATADO').mean().sort_values('MEDIA').plot(kind='bar', figsize=(10,10))
df_notas_media2.set_ylim(500,545)
# Out:
# (500, 545)

# %% [markdown]
# ### Conclusão:
#
# Quando mais recente a formação do candidato tem a tendência de maior nota.

# %% [markdown]
# # Eliminados em prova - ENEM 2018

# %%
df_eliminados = df.loc[:,['SG_UF_RESIDENCIA', 'TP_PRESENCA_CN', 'TP_PRESENCA_CH', 'TP_PRESENCA_LC', 'TP_PRESENCA_MT']]

# %%
df_eliminados.sample(10)
# Out:
#         SG_UF_RESIDENCIA  TP_PRESENCA_CN  TP_PRESENCA_CH  TP_PRESENCA_LC  \
# 839883                SP             0.0             0.0             0.0
# 405562                SP             1.0             1.0             1.0
# 2236721               RJ             1.0             1.0             1.0
# 2411004               BA             1.0             1.0             1.0
# 1113320               AM             0.0             0.0             0.0
# 2966396               MG             1.0             1.0             1.0
# 1563151               MS             1.0             1.0             1.0
# 2722118               SP             1.0             1.0             1.0
# 608492                GO             0.0             1.0             1.0
# 753135                SP             1.0             1.0             1.0
#
#          TP_PRESENCA_MT
# 839883              0.0
# 405562              1.0
# 2236721             1.0
# 2411004             1.0
# 1113320             0.0
# ...

# %% [markdown]
# Separação dos candidatos que foram eliminados

# %%
df_eliminados.query('TP_PRESENCA_CN == 2 or TP_PRESENCA_CH == 2 or TP_PRESENCA_LC == 2 or TP_PRESENCA_MT == 2').sample(10)
# Out:
#         SG_UF_RESIDENCIA  TP_PRESENCA_CN  TP_PRESENCA_CH  TP_PRESENCA_LC  \
# 1865345               RJ             2.0             1.0             1.0
# 3859193               CE             2.0             1.0             1.0
# 4733100               RN             0.0             2.0             2.0
# 3880883               RO             0.0             2.0             2.0
# 4698842               MA             2.0             1.0             1.0
# 3030232               SP             0.0             2.0             2.0
# 2398643               MG             0.0             2.0             2.0
# 2728175               MG             0.0             2.0             2.0
# 612166                BA             1.0             2.0             2.0
# 4491811               PR             0.0             2.0             2.0
#
#          TP_PRESENCA_MT
# 1865345             2.0
# 3859193             2.0
# 4733100             0.0
# 3880883             0.0
# 4698842             2.0
# ...

# %%
df_eliminados.query('TP_PRESENCA_CN == 2 or TP_PRESENCA_CH == 2 or TP_PRESENCA_LC == 2 or TP_PRESENCA_MT == 2').groupby('SG_UF_RESIDENCIA')['TP_PRESENCA_CN'].count()
# Out:
# SG_UF_RESIDENCIA
# AC     18
# AL     35
# AM     44
# AP     21
# BA    100
# CE    145
# DF     27
# ES     50
# GO     95
# MA     82
# MG    319
# MS     67
# MT     44
# PA     85
# PB     68
# PE    103
# PI     37
# PR    178
# RJ    150
# RN     65
# RO     24
# RR      4
# RS    113
# SC    110
# SE     35
# SP    537
# TO     28
# Name: TP_PRESENCA_CN, dtype: int64

# %%
df_eliminados.query('TP_PRESENCA_CN == 2 or TP_PRESENCA_CH == 2 or TP_PRESENCA_LC == 2 or TP_PRESENCA_MT == 2').groupby('SG_UF_RESIDENCIA')['TP_PRESENCA_CN'].count().plot(kind='bar',figsize=(10,5))

# %%
df_eliminados.groupby('SG_UF_RESIDENCIA')['TP_PRESENCA_CN'].count()
# Out:
# SG_UF_RESIDENCIA
# AC     37784
# AL     89670
# AM    123754
# AP     40107
# BA    401325
# CE    329399
# DF    104519
# ES    112170
# GO    191028
# MA    218454
# MG    587451
# MS     72311
# MT     96757
# PA    283855
# PB    152043
# PE    304299
# PI    118346
# PR    236526
# RJ    382073
# RN    124032
# RO     62260
# RR     14029
# RS    243547
# SC    123931
# SE     74633
# SP    934151
# TO     55138
# Name: TP_PRESENCA_CN, dtype: int64

# %%
df_candidatos = df_eliminados.groupby('SG_UF_RESIDENCIA')['TP_PRESENCA_CN'].count()
df_candidatos_eliminados = df_eliminados.query('TP_PRESENCA_CN == 2 or TP_PRESENCA_CH == 2 or TP_PRESENCA_LC == 2 or TP_PRESENCA_MT == 2').groupby('SG_UF_RESIDENCIA')['TP_PRESENCA_CN'].count()

# %%
df_unificado = pd.merge(df_candidatos, df_candidatos_eliminados, on = 'SG_UF_RESIDENCIA')

# %%
df_unificado.rename(columns={'SG_UF_RESIDENCIA': 'ESTADO',
                   'TP_PRESENCA_CN_x': 'TOTAL_CANDIDATOS',
                   'TP_PRESENCA_CN_y': 'CANDIDADOS_DESCLASSIFICADOS'
                  }, inplace=True)

df_unificado.sample(27)
# Out:
#                   TOTAL_CANDIDATOS  CANDIDADOS_DESCLASSIFICADOS
# SG_UF_RESIDENCIA
# BA                          401325                          100
# AC                           37784                           18
# RS                          243547                          113
# AM                          123754                           44
# PR                          236526                          178
# PA                          283855                           85
# SE                           74633                           35
# PI                          118346                           37
# RJ                          382073                          150
# SP                          934151                          537
# AP                           40107                           21
# MA                          218454                           82
# SC                          123931                          110
# ...

# %%
df_unificado_tratado = df_unificado['PERCENTUAL_DESCLASSIFICADO'] = 100 - (df_unificado['TOTAL_CANDIDATOS'] 
                                              - df_unificado['CANDIDADOS_DESCLASSIFICADOS']) / df_unificado['TOTAL_CANDIDATOS'] * 100
df_unificado.sample(27).sort_values('PERCENTUAL_DESCLASSIFICADO', ascending=False)
# Out:
#                   TOTAL_CANDIDATOS  CANDIDADOS_DESCLASSIFICADOS  \
# SG_UF_RESIDENCIA
# MS                           72311                           67
# SC                          123931                          110
# PR                          236526                          178
# SP                          934151                          537
# MG                          587451                          319
# RN                          124032                           65
# AP                           40107                           21
# TO                           55138                           28
# GO                          191028                           95
# AC                           37784                           18
# SE                           74633                           35
# RS                          243547                          113
# MT                           96757                           44
# ...

# %%
df_unificado_tratado.sample(27)
# Out:
# SG_UF_RESIDENCIA
# SC    0.088759
# RJ    0.039260
# TO    0.050782
# PB    0.044724
# DF    0.025833
# SP    0.057485
# MA    0.037537
# ES    0.044575
# SE    0.046896
# RR    0.028512
# PE    0.033848
# RO    0.038548
# PA    0.029945
# PI    0.031264
# PR    0.075256
# MG    0.054302
# BA    0.024917
# RS    0.046398
# RN    0.052406
# GO    0.049731
# CE    0.044020
# AL    0.039032
# AM    0.035554
# MS    0.092655
# AP    0.052360
# MT    0.045475
# AC    0.047639
# dtype: float64

# %%
df_unificado_tratado.plot(kind='bar',figsize=(10,5))

# %% [markdown]
# ### Conclusão:
#
# Não foi o Estado com mais candidatos que foi a maior desclassificação.
